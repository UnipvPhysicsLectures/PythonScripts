# %% [markdown]
# ## Libraries

# %%
# libraries
import numpy as np
import matplotlib.pylab as plt

# %%
n_step = 100
x = np.linspace(-4,4,n_step)
x_ind = np.linspace(-6,6,n_step)
y_valence = -x**2
y_cond = 5 + 2*x**2
y_cond_ind = np.sqrt(100 + x_ind**4 -10*(x_ind-1)**2)
f_size = 40

# %%
fig,ax = plt.subplots(figsize=(8,8))

# Move the left and bottom spines to x = 0 and y = 0, respectively.
ax.spines[["left", "bottom"]].set_position(("data", 0))
ax.set_axisbelow(True)

# Hide the top and right spines.
ax.spines[["top", "right"]].set_visible(False)

# Draw arrows (as black triangles: ">k"/"^k") at the end of the axes.  In each
# case, one of the coordinates (0) is a data coordinate (i.e., y = 0 or x = 0,
# respectively) and the other one (1) is an axes coordinate (i.e., at the very
# right/top of the axes).  Also, disable clipping (clip_on=False) as the marker
# actually spills out of the axes.
# ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
# ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)

# change all spines
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)

# increase tick width
ax.tick_params(width=4)

ax.plot(x,y_valence,linewidth = 6.0, label= 'Valence Band')
ax.plot(x,y_cond,linewidth = 6.0, label= 'Conduction Band')

# ticks
ax.set_xticks([])
ax.set_yticks([])

# labels
ax.set_xlabel('k',fontsize=f_size,loc='right')
ax.set_ylabel('E',fontsize=f_size,loc='top')

# legend
ax.legend(fontsize=f_size-20,loc='upper right')

# limits
ax.set_xlim(-8,8)

# save
fig.set_tight_layout('tight')
fig.savefig('../figures/directBand.png',dpi=300)

# %%
fig,ax = plt.subplots(figsize=(8,8))

# Move the left and bottom spines to x = 0 and y = 0, respectively.
ax.spines[["left", "bottom"]].set_position(("data", 0))
ax.set_axisbelow(True)

# Hide the top and right spines.
ax.spines[["top", "right"]].set_visible(False)

# Draw arrows (as black triangles: ">k"/"^k") at the end of the axes.  In each
# case, one of the coordinates (0) is a data coordinate (i.e., y = 0 or x = 0,
# respectively) and the other one (1) is an axes coordinate (i.e., at the very
# right/top of the axes).  Also, disable clipping (clip_on=False) as the marker
# actually spills out of the axes.
# ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
# ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)

# change all spines
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)

# increase tick width
ax.tick_params(width=4)

ax.plot(x,-2.5 + y_valence,linewidth = 6.0, label= 'Valence Band')
ax.plot(x,-2.5+ y_cond,linewidth = 6.0, label= 'Conduction Band')

# ticks
ax.set_xticks([])
ax.set_yticks([])

# labels
ax.set_xlabel('k',fontsize=f_size,loc='right')
ax.set_ylabel('E',fontsize=f_size,loc='top')

# legend
ax.legend(fontsize=f_size-20,loc='upper right')

# limits
ax.set_xlim(-8,8)

# save
fig.set_tight_layout('tight')
fig.savefig('../figures/directBandSim.png',dpi=300)

# %%
fig,ax = plt.subplots(figsize=(8,8))

# Move the left and bottom spines to x = 0 and y = 0, respectively.
ax.spines[["left", "bottom"]].set_position(("data", 0))
ax.set_axisbelow(True)

# Hide the top and right spines.
ax.spines[["top", "right"]].set_visible(False)

# Draw arrows (as black triangles: ">k"/"^k") at the end of the axes.  In each
# case, one of the coordinates (0) is a data coordinate (i.e., y = 0 or x = 0,
# respectively) and the other one (1) is an axes coordinate (i.e., at the very
# right/top of the axes).  Also, disable clipping (clip_on=False) as the marker
# actually spills out of the axes.
# ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)
# ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)

# change all spines
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)

# increase tick width
ax.tick_params(width=4)

ax.plot(x,y_valence,linewidth = 4.0, label= 'Valence Band')
ax.plot(-x,y_cond_ind,linewidth = 4.0, label= 'Conduction Band')

# ticks
ax.set_xticks([])
ax.set_yticks([])

# labels
ax.set_xlabel('k',fontsize=f_size,loc='right')
ax.set_ylabel('E',fontsize=f_size,loc='top')

# legend
ax.legend(fontsize=f_size-20,loc='upper right')

# limits
ax.set_xlim(-8,8)

# save
fig.set_tight_layout('tight')
fig.savefig('../figures/indirectBand.png',dpi=300)
